# %% [markdown]
# <a href="https://colab.research.google.com/github/Vasavi430/Cursor/blob/main/day4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install opendatasets

# %%
import opendatasets as od

# %%
od.download("https://www.kaggle.com/datasets/brendan45774/test-file")
# Out:
# Please provide your Kaggle credentials to download this dataset. Learn more: http://bit.ly/kaggle-creds
# Your Kaggle username: vasavisuthapalli
# Your Kaggle Key: ··········
# Dataset URL: https://www.kaggle.com/datasets/brendan45774/test-file
# ...
# 100%|██████████| 11.2k/11.2k [00:00<00:00, 2.54MB/s]

# %%
import pandas as pd
data = pd.read_csv('/content/test-file/tested.csv')

# %%
data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
#
#     Ticket     Fare Cabin Embarked
# 0   330911   7.8292   NaN        Q
# 1   363272   7.0000   NaN        S
# 2   240276   9.6875   NaN        Q
# 3   315154   8.6625   NaN        S
# 4  3101298  12.2875   NaN        S

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Survived     418 non-null    int64
#  2   Pclass       418 non-null    int64
#  3   Name         418 non-null    object
#  4   Sex          418 non-null    object
#  5   Age          332 non-null    float64
#  6   SibSp        418 non-null    int64
#  7   Parch        418 non-null    int64
#  8   Ticket       418 non-null    object
#  9   Fare         417 non-null    float64
#  10  Cabin        91 non-null     object
#  11  Embarked     418 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 39.3+ KB

# %%
data.Fare
# Out:
# 0        7.8292
# 1        7.0000
# 2        9.6875
# 3        8.6625
# 4       12.2875
#          ...
# 413      8.0500
# 414    108.9000
# 415      7.2500
# 416      8.0500
# 417     22.3583
# Name: Fare, Length: 418, dtype: float64

# %%
data.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
data.axes[0]
# Out:
# RangeIndex(start=0, stop=418, step=1)

# %%
data.index
# Out:
# RangeIndex(start=0, stop=418, step=1)

# %%
data.Age
# Out:
# 0      34.5
# 1      47.0
# 2      62.0
# 3      27.0
# 4      22.0
#        ...
# 413     NaN
# 414    39.0
# 415    38.5
# 416     NaN
# 417     NaN
# Name: Age, Length: 418, dtype: float64

# %%
data.PassengerId
# Out:
# 0       892
# 1       893
# 2       894
# 3       895
# 4       896
#        ...
# 413    1305
# 414    1306
# 415    1307
# 416    1308
# 417    1309
# Name: PassengerId, Length: 418, dtype: int64

# %%
data.Ticket
# Out:
# 0                  330911
# 1                  363272
# 2                  240276
# 3                  315154
# 4                 3101298
#               ...
# 413             A.5. 3236
# 414              PC 17758
# 415    SOTON/O.Q. 3101262
# 416                359309
# 417                  2668
# Name: Ticket, Length: 418, dtype: object

# %%
data.tail()
# Out:
#      PassengerId  Survived  Pclass                          Name     Sex  \
# 413         1305         0       3            Spector, Mr. Woolf    male
# 414         1306         1       1  Oliva y Ocana, Dona. Fermina  female
# 415         1307         0       3  Saether, Mr. Simon Sivertsen    male
# 416         1308         0       3           Ware, Mr. Frederick    male
# 417         1309         0       3      Peter, Master. Michael J    male
#
#       Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# 413   NaN      0      0           A.5. 3236    8.0500   NaN        S
# 414  39.0      0      0            PC 17758  108.9000  C105        C
# 415  38.5      0      0  SOTON/O.Q. 3101262    7.2500   NaN        S
# 416   NaN      0      0              359309    8.0500   NaN        S
# 417   NaN      1      1                2668   22.3583   NaN        C

# %%
data.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   418.000000  418.000000  418.000000  332.000000  418.000000
# mean   1100.500000    0.363636    2.265550   30.272590    0.447368
# std     120.810458    0.481622    0.841838   14.181209    0.896760
# min     892.000000    0.000000    1.000000    0.170000    0.000000
# 25%     996.250000    0.000000    1.000000   21.000000    0.000000
# 50%    1100.500000    0.000000    3.000000   27.000000    0.000000
# 75%    1204.750000    1.000000    3.000000   39.000000    1.000000
# max    1309.000000    1.000000    3.000000   76.000000    8.000000
#
#             Parch        Fare
# count  418.000000  417.000000
# mean     0.392344   35.627188
# std      0.981429   55.907576
# min      0.000000    0.000000
# 25%      0.000000    7.895800
# 50%      0.000000   14.454200
# 75%      0.000000   31.500000
# max      9.000000  512.329200

# %%
data.sample()
# Out:
#      PassengerId  Survived  Pclass                      Name   Sex   Age  \
# 204         1096         0       2  Andrew, Mr. Frank Thomas  male  25.0
#
#      SibSp  Parch      Ticket  Fare Cabin Embarked
# 204      0      0  C.A. 34050  10.5   NaN        S

# %%
data.dropna()
# Out:
#      PassengerId  Survived  Pclass  \
# 12           904         1       1
# 14           906         1       1
# 24           916         1       1
# 26           918         1       1
# 28           920         0       1
# ..           ...       ...     ...
# 404         1296         0       1
# 405         1297         0       2
# 407         1299         0       1
# 411         1303         1       1
# 414         1306         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 12       Snyder, Mrs. John Pillsbury (Nelle Stevenson)  female  23.0      1
# 14   Chaffee, Mrs. Herbert Fuller (Carrie Constance...  female  47.0      1
# 24     Ryerson, Mrs. Arthur Larned (Emily Maria Borie)  female  48.0      1
# 26                        Ostby, Miss. Helene Ragnhild  female  22.0      0
# 28                             Brady, Mr. John Bertram    male  41.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
data.SibSp
# Out:
# 0      0
# 1      1
# 2      0
# 3      0
# 4      1
#       ..
# 413    0
# 414    0
# 415    0
# 416    0
# 417    1
# Name: SibSp, Length: 418, dtype: int64

# %%
data.size
# Out:
# 5016

# %%
data.shape
# Out:
# (418, 12)

# %%
import numpy as np
np.mean(data["Age"].dropna())  # Result is calculated but not stored
# Out:
# 30.272590361445783

# %%
np.max(data["Fare"].dropna())
# Out:
# 512.3292

# %%
np.array(data["Pclass"])
# Out:
# array([3, 3, 2, 3, 3, 3, 3, 2, 3, 3, 3, 1, 1, 2, 1, 2, 2, 3, 3, 3, 1, 3,
#        1, 1, 1, 3, 1, 3, 1, 3, 2, 2, 3, 3, 1, 3, 3, 3, 3, 3, 3, 1, 3, 2,
#        1, 3, 1, 3, 1, 3, 1, 2, 2, 1, 2, 3, 3, 3, 3, 1, 3, 2, 3, 3, 1, 2,
#        3, 1, 1, 1, 3, 3, 3, 1, 1, 1, 3, 1, 2, 3, 3, 1, 1, 3, 2, 3, 3, 3,
#        3, 2, 3, 3, 1, 3, 1, 3, 1, 3, 3, 3, 1, 2, 3, 3, 3, 3, 3, 3, 3, 2,
#        2, 3, 1, 3, 1, 3, 3, 3, 1, 2, 2, 3, 1, 3, 3, 3, 3, 3, 2, 3, 3, 1,
#        3, 3, 3, 3, 3, 2, 3, 3, 3, 1, 1, 2, 1, 3, 1, 3, 1, 2, 1, 3, 3, 3,
#        3, 3, 1, 3, 1, 3, 3, 3, 2, 3, 2, 3, 1, 3, 1, 3, 3, 3, 3, 3, 3, 2,
#        2, 1, 2, 1, 2, 1, 1, 3, 1, 2, 2, 3, 3, 2, 2, 1, 3, 2, 2, 3, 1, 3,
#        2, 3, 3, 3, 1, 2, 2, 1, 3, 2, 1, 3, 3, 3, 2, 2, 3, 1, 3, 1, 1, 3,
#        2, 3, 2, 3, 1, 3, 3, 3, 3, 2, 2, 1, 3, 3, 1, 3, 1, 3, 2, 1, 1, 2,
#        1, 3, 3, 1, 2, 2, 2, 3, 2, 3, 1, 3, 3, 3, 3, 3, 2, 3, 3, 3, 2, 3,
#        2, 3, 1, 3, 3, 3, 1, 3, 1, 3, 3, 2, 2, 2, 2, 2, 3, 3, 3, 3, 3, 3,
# ...

# %%
np.array(data["Pclass"]).reshape((-1, 1))
# Out:
# array([[3],
#        [3],
#        [2],
#        [3],
#        [3],
#        [3],
#        [3],
#        [2],
#        [3],
#        [3],
#        [3],
#        [1],
#        [1],
#        [2],
#        [1],
#        [2],
#        [2],
#        [3],
#        [3],
#        [3],
#        [1],
#        [3],
#        [1],
#        [1],
#        [1],
#        [3],
#        [1],
#        [3],
#        [1],
#        [3],
#        [2],
#        [2],
#        [3],
#        [3],
#        [1],
#        [3],
#        [3],
#        [3],
#        [3],
#        [3],
#        [3],
#        [1],
#        [3],
#        [2],
#        [1],
#        [3],
#        [1],
#        [3],
#        [1],
#        [3],
#        [1],
#        [2],
#        [2],
#        [1],
#        [2],
#        [3],
#        [3],
#        [3],
#        [3],
#        [1],
#        [3],
#        [2],
#        [3],
#        [3],
#        [1],
#        [2],
#        [3],
#        [1],
#        [1],
#        [1],
#        [3],
# ...

# %%
np.std(data["Fare"].dropna())
# Out:
# 55.84050047954103

# %%
np.where(data["Age"].dropna() > 30)
# Out:
# (array([  0,   1,   2,  10,  12,  13,  15,  18,  19,  22,  23,  26,  27,
#          29,  34,  35,  37,  39,  40,  41,  47,  49,  51,  56,  57,  58,
#          63,  64,  65,  69,  70,  78,  81,  82,  89,  90,  92,  95,  98,
#         102, 104, 105, 106, 111, 113, 114, 116, 117, 121, 122, 127, 131,
#         133, 138, 141, 142, 143, 145, 148, 151, 152, 154, 156, 161, 164,
#         166, 168, 170, 171, 172, 173, 174, 179, 181, 182, 186, 188, 191,
#         192, 193, 194, 195, 197, 203, 207, 213, 217, 224, 227, 228, 233,
#         234, 236, 239, 240, 243, 244, 246, 253, 254, 257, 260, 261, 265,
#         266, 269, 270, 273, 275, 276, 279, 281, 282, 286, 290, 293, 294,
#         295, 296, 297, 300, 306, 310, 312, 316, 318, 320, 323, 326, 328,
#         330, 331]),)

# %%
np.sum(data["SibSp"])
# Out:
# 187

# %%
np.min(data["Parch"])
# Out:
# 0

# %%
np.unique(data["Pclass"], return_counts=True)
# Out:
# (array([1, 2, 3]), array([107,  93, 218]))

# %%
np.unique(data["Pclass"], return_counts=True)
# Out:
# (array([1, 2, 3]), array([107,  93, 218]))

# %%
np.var(data["Age"].dropna())
# Out:
# 200.50095232617215

# %%
np.percentile(data["Fare"].dropna(), 75)
# Out:
# 31.5

# %%
data["Fare"].values.sort()

# %%
age_fare = data[["Age", "Fare"]].dropna()
np.corrcoef(age_fare["Age"],
            age_fare["Fare"])
# Out:
# array([[ 1.        , -0.01179997],
#        [-0.01179997,  1.        ]])

# %%
np.histogram(data["Age"].dropna())
# Out:
# (array([16, 16, 71, 97, 43, 37, 25, 17,  9,  1]),
#  array([ 0.17 ,  7.753, 15.336, 22.919, 30.502, 38.085, 45.668, 53.251,
#         60.834, 68.417, 76.   ]))

# %%
data.plot(kind='scatter', x='Age', y='Fare')
# Out:
# <Axes: xlabel='Age', ylabel='Fare'>
