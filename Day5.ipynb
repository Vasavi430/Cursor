# %% [markdown]
# <a href="https://colab.research.google.com/github/Vasavi430/Cursor/blob/main/Day5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('/content/tourism_amazon.csv')

# %%
df.isnull().sum()
# Out:
# status_id             0
# status_message        0
# link_name           463
# status_type           0
# status_link          12
# status_published      0
# num_reactions         0
# num_comments          0
# num_shares            0
# num_likes             0
# num_loves             0
# num_wows              0
# num_hahas             0
# num_sads              0
# num_angrys            0
# num_special           0
# category            338
# dtype: int64

# %%
df.dropna()
# Out:
#                               status_id  \
# 1     1549033165419320_2139793586343272
# 3       380000952157262_965919786898706
# 4     1491715331132829_1777940962510263
# 5     1549061578692287_2018356398429467
# 6      325932867434253_1979059738788216
# ...                                 ...
# 1007   501573163236918_1847719375288950
# 1011    350885085102744_773859869471928
# 1012   501573163236918_1791206094273612
# 1016    350885085102744_798507237007191
# 1017    350885085102744_778923848965530
#
#                                          status_message  \
# 1     Todo mundo curte um hot roll. E quem negar, me...
# 3     Nosso Filé com Molho de Vinho é fabuloso! Ele ...
# 4                Daqui a pouco tem Malino’s Hein!\n🍔🍺🍟😍
# 5     Você sabia que além de hambúrgueres,temos tamb...
# 6     Que esse é um dos pratos mais famosos e respei...
# ...                                                 ...
# 1007                                  fotos; JOEL DINIZ
# ...

# %%
df.duplicated().sum()
# Out:
# 3

# %%
df.drop_duplicates()
# Out:
#                               status_id  \
# 0     1549061578692287_2021387448126362
# 1     1549033165419320_2139793586343272
# 2     1549061578692287_2042133349385105
# 3       380000952157262_965919786898706
# 4     1491715331132829_1777940962510263
# ...                                 ...
# 1013   216753025121174_1531868880276242
# 1014   365838463497691_1709821622432695
# 1015   156461724431781_1643086925769246
# 1016    350885085102744_798507237007191
# 1017    350885085102744_778923848965530
#
#                                          status_message  \
# 0                               Vamos tomar chopp hoje😍
# 1     Todo mundo curte um hot roll. E quem negar, me...
# 2                             Mesa cheia é mesa alegre!
# 3     Nosso Filé com Molho de Vinho é fabuloso! Ele ...
# 4                Daqui a pouco tem Malino’s Hein!\n🍔🍺🍟😍
# ...                                                 ...
# 1013                                  Queijo coalho.😋😋😋
# ...

# %%
df.dtypes
# Out:
# status_id            object
# status_message       object
# link_name            object
# status_type          object
# status_link          object
# status_published     object
# num_reactions       float64
# num_comments        float64
# num_shares          float64
# num_likes           float64
# num_loves           float64
# num_wows            float64
# num_hahas           float64
# num_sads            float64
# num_angrys          float64
# num_special         float64
# category            float64
# dtype: object

# %%
df.fillna()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-13-d3a028362a04> in <cell line: 1>()
# ----> 1 df.fillna()
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in fillna(self, value, method, axis, inplace, limit, downcast)
#    7291                     )
#    7292
# -> 7293         value, method = validate_fillna_kwargs(value, method)
#    7294         if method is not None:
#    7295             warnings.warn(
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_validators.py in validate_fillna_kwargs(value, method, validate_scalar_dict_value)
#     291
#     292     if value is None and method is None:
# --> 293         raise ValueError("Must specify a fill 'value' or 'method'.")
#     294     if value is None and method is not None:
#     295         method = clean_fill_method(method)
#
# ValueError: Must specify a fill 'value' or 'method'.

# %%
missing_values=["N/a","na",np.nan]
df=pd.read_csv('/content/tourism_amazon.csv',na_values=missing_values)

# %%
df.isnull().any()
# Out:
# status_id           False
# status_message      False
# link_name            True
# status_type         False
# status_link          True
# status_published    False
# num_reactions       False
# num_comments        False
# num_shares          False
# num_likes           False
# num_loves           False
# num_wows            False
# num_hahas           False
# num_sads            False
# num_angrys          False
# num_special         False
# category             True
# dtype: bool

# %%
df.describe()
# Out:
#        num_reactions  num_comments   num_shares    num_likes    num_loves  \
# count    1018.000000   1018.000000  1018.000000  1018.000000  1018.000000
# mean       86.052063      7.009823     2.852652    79.478389     4.294695
# std       224.752437     43.952015    10.821148   206.735021    14.400835
# min         0.000000      0.000000     0.000000     0.000000     0.000000
# 25%         3.000000      0.000000     0.000000     3.000000     0.000000
# 50%        10.000000      0.000000     0.000000     9.000000     0.000000
# 75%        44.750000      1.000000     2.000000    38.750000     2.000000
# max      2063.000000    819.000000   163.000000  1944.000000   201.000000
#
#           num_wows    num_hahas     num_sads   num_angrys  num_special  \
# count  1018.000000  1018.000000  1018.000000  1018.000000       1018.0
# mean      1.238703     0.990177     0.036346     0.013752          0.0
# std       5.107401    13.036742     0.378445     0.124672          0.0
# ...

# %%
df
# Out:
#                               status_id  \
# 0     1549061578692287_2021387448126362
# 1     1549033165419320_2139793586343272
# 2     1549061578692287_2042133349385105
# 3       380000952157262_965919786898706
# 4     1491715331132829_1777940962510263
# ...                                 ...
# 1013   216753025121174_1531868880276242
# 1014   365838463497691_1709821622432695
# 1015   156461724431781_1643086925769246
# 1016    350885085102744_798507237007191
# 1017    350885085102744_778923848965530
#
#                                          status_message  \
# 0                               Vamos tomar chopp hoje😍
# 1     Todo mundo curte um hot roll. E quem negar, me...
# 2                             Mesa cheia é mesa alegre!
# 3     Nosso Filé com Molho de Vinho é fabuloso! Ele ...
# 4                Daqui a pouco tem Malino’s Hein!\n🍔🍺🍟😍
# ...                                                 ...
# 1013                                  Queijo coalho.😋😋😋
# ...

# %%
df.mean(numeric_only=True)
# Out:
# num_reactions    86.052063
# num_comments      7.009823
# num_shares        2.852652
# num_likes        79.478389
# num_loves         4.294695
# num_wows          1.238703
# num_hahas         0.990177
# num_sads          0.036346
# num_angrys        0.013752
# num_special       0.000000
# category          2.201471
# dtype: float64

# %%
df.fillna(df.mean(numeric_only=True))
# Out:
#                               status_id  \
# 0     1549061578692287_2021387448126362
# 1     1549033165419320_2139793586343272
# 2     1549061578692287_2042133349385105
# 3       380000952157262_965919786898706
# 4     1491715331132829_1777940962510263
# ...                                 ...
# 1013   216753025121174_1531868880276242
# 1014   365838463497691_1709821622432695
# 1015   156461724431781_1643086925769246
# 1016    350885085102744_798507237007191
# 1017    350885085102744_778923848965530
#
#                                          status_message  \
# 0                               Vamos tomar chopp hoje😍
# 1     Todo mundo curte um hot roll. E quem negar, me...
# 2                             Mesa cheia é mesa alegre!
# 3     Nosso Filé com Molho de Vinho é fabuloso! Ele ...
# 4                Daqui a pouco tem Malino’s Hein!\n🍔🍺🍟😍
# ...                                                 ...
# 1013                                  Queijo coalho.😋😋😋
# ...

# %%
df.mode()
# Out:
#                           status_id  \
# 0  501573163236918_1829727257088162
# 1  501573163236918_1841133475947540
# 2  501573163236918_1855553941172160
#
#                                       status_message        link_name  \
# 0  Hoje tem desconto nos:\nSandubas de Frango + S...  Timeline Photos
# 1  Hoje tem pão delícia, o nosso pãozinho de bata...              NaN
# 2  Rodízio de sushi e pratos quentes, por apenas ...              NaN
#
#   status_type                                        status_link  \
# 0       photo  https://www.facebook.com/simboraentretenimemto...
# 1         NaN  https://www.facebook.com/simboraentretenimemto...
# 2         NaN  https://www.facebook.com/simboraentretenimemto...
#
#       status_published  num_reactions  num_comments  num_shares  num_likes  \
# 0  2018-04-30 13:21:25            1.0           0.0         0.0        1.0
# 1  2018-05-07 19:10:12            NaN           NaN         NaN        NaN
# ...

# %%
df.fillna(df.mode())
# Out:
#                               status_id  \
# 0     1549061578692287_2021387448126362
# 1     1549033165419320_2139793586343272
# 2     1549061578692287_2042133349385105
# 3       380000952157262_965919786898706
# 4     1491715331132829_1777940962510263
# ...                                 ...
# 1013   216753025121174_1531868880276242
# 1014   365838463497691_1709821622432695
# 1015   156461724431781_1643086925769246
# 1016    350885085102744_798507237007191
# 1017    350885085102744_778923848965530
#
#                                          status_message  \
# 0                               Vamos tomar chopp hoje😍
# 1     Todo mundo curte um hot roll. E quem negar, me...
# 2                             Mesa cheia é mesa alegre!
# 3     Nosso Filé com Molho de Vinho é fabuloso! Ele ...
# 4                Daqui a pouco tem Malino’s Hein!\n🍔🍺🍟😍
# ...                                                 ...
# 1013                                  Queijo coalho.😋😋😋
# ...

# %%
df.select_dtypes(include=['float64']).median()
# Out:
# num_reactions    10.0
# num_comments      0.0
# num_shares        0.0
# num_likes         9.0
# num_loves         0.0
# num_wows          0.0
# num_hahas         0.0
# num_sads          0.0
# num_angrys        0.0
# num_special       0.0
# category          2.0
# dtype: float64

# %%
df.median(numeric_only=True)
# Out:
# num_reactions    10.0
# num_comments      0.0
# num_shares        0.0
# num_likes         9.0
# num_loves         0.0
# num_wows          0.0
# num_hahas         0.0
# num_sads          0.0
# num_angrys        0.0
# num_special       0.0
# category          2.0
# dtype: float64

# %%
df.fillna(df.median(numeric_only=True))
# Out:
#                               status_id  \
# 0     1549061578692287_2021387448126362
# 1     1549033165419320_2139793586343272
# 2     1549061578692287_2042133349385105
# 3       380000952157262_965919786898706
# 4     1491715331132829_1777940962510263
# ...                                 ...
# 1013   216753025121174_1531868880276242
# 1014   365838463497691_1709821622432695
# 1015   156461724431781_1643086925769246
# 1016    350885085102744_798507237007191
# 1017    350885085102744_778923848965530
#
#                                          status_message  \
# 0                               Vamos tomar chopp hoje😍
# 1     Todo mundo curte um hot roll. E quem negar, me...
# 2                             Mesa cheia é mesa alegre!
# 3     Nosso Filé com Molho de Vinho é fabuloso! Ele ...
# 4                Daqui a pouco tem Malino’s Hein!\n🍔🍺🍟😍
# ...                                                 ...
# 1013                                  Queijo coalho.😋😋😋
# ...

# %%
df.describe()
# Out:
#        num_reactions  num_comments   num_shares    num_likes    num_loves  \
# count    1018.000000   1018.000000  1018.000000  1018.000000  1018.000000
# mean       86.052063      7.009823     2.852652    79.478389     4.294695
# std       224.752437     43.952015    10.821148   206.735021    14.400835
# min         0.000000      0.000000     0.000000     0.000000     0.000000
# 25%         3.000000      0.000000     0.000000     3.000000     0.000000
# 50%        10.000000      0.000000     0.000000     9.000000     0.000000
# 75%        44.750000      1.000000     2.000000    38.750000     2.000000
# max      2063.000000    819.000000   163.000000  1944.000000   201.000000
#
#           num_wows    num_hahas     num_sads   num_angrys  num_special  \
# count  1018.000000  1018.000000  1018.000000  1018.000000       1018.0
# mean      1.238703     0.990177     0.036346     0.013752          0.0
# std       5.107401    13.036742     0.378445     0.124672          0.0
# ...

# %%
import seaborn as sns
sns.displot(df['num_wows'])

# %%
sns.boxplot(df['num_wows'])
# Out:
# <Axes: ylabel='num_wows'>
