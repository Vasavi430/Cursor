# %% [markdown]
# <a href="https://colab.research.google.com/github/Vasavi430/Cursor/blob/main/Day6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install opendatasets

# %%
import opendatasets as od

# %%
od.download("https://www.kaggle.com/datasets/earthfromtop/amazon-sales-fy202021")
# Out:
# Please provide your Kaggle credentials to download this dataset. Learn more: http://bit.ly/kaggle-creds
# Your Kaggle username: vasavisuthapalli
# Your Kaggle Key: ··········
# Dataset URL: https://www.kaggle.com/datasets/earthfromtop/amazon-sales-fy202021
# ...
# 100%|██████████| 11.6M/11.6M [00:00<00:00, 72.6MB/s]

# %%
import pandas as pd
data = pd.read_csv('/content/amazon-sales-fy202021/Amazon Sales FY2020-21.csv')
# Out:
# <ipython-input-35-f0aba699ddb5>:2: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv('/content/amazon-sales-fy202021/Amazon Sales FY2020-21.csv')

# %%
df
# Out:
#                               status_id  \
# 0     1549061578692287_2021387448126362
# 1     1549033165419320_2139793586343272
# 2     1549061578692287_2042133349385105
# 3       380000952157262_965919786898706
# 4     1491715331132829_1777940962510263
# ...                                 ...
# 1013   216753025121174_1531868880276242
# 1014   365838463497691_1709821622432695
# 1015   156461724431781_1643086925769246
# 1016    350885085102744_798507237007191
# 1017    350885085102744_778923848965530
#
#                                          status_message  \
# 0                               Vamos tomar chopp hoje😍
# 1     Todo mundo curte um hot roll. E quem negar, me...
# 2                             Mesa cheia é mesa alegre!
# 3     Nosso Filé com Molho de Vinho é fabuloso! Ele ...
# 4                Daqui a pouco tem Malino’s Hein!\n🍔🍺🍟😍
# ...                                                 ...
# 1013                                  Queijo coalho.😋😋😋
# ...

# %%
import matplotlib.pyplot as plt

x_values=df['num_loves']
y_values=df['num_sads']

plt.scatter(x_values,y_values)

# %%
plt.plot(x_values, y_values)

# %%
import seaborn as sns

# %%
sns.scatterplot(x=x_values, y=y_values)
# Out:
# <Axes: xlabel='num_loves', ylabel='num_sads'>

# %%
sns.histplot(x=y_values)  # Histogram of Q19 values
# Out:
# <Axes: xlabel='num_sads', ylabel='Count'>

# %%
sns.barplot(x=x_values, y=y_values)
plt.show()

# %%
sns.lineplot(x=x_values, y=y_values)
# Out:
# <Axes: xlabel='num_loves', ylabel='num_sads'>

# %%
import scipy.stats as stats
# Number of trials
n = 10

# Probability of success
p = 0.5

# Calculate x-axis values (number of successes from 0 to n)
x_values = np.arange(0, n + 1)

# Calculate PMF directly using binom.pmf
y_values = stats.binom.pmf(x_values, n, p)

# Create the plot
plt.bar(x_values, y_values)
plt.xlabel('Number of Successes')
plt.ylabel('Probability')
plt.title('Binomial Distribution PMF')
plt.show()

# %%
import seaborn as sns

import pandas as pd

import numpy as np



# Sample DataFrame

df = pd.DataFrame(np.random.randn(10, 5), columns=['A', 'B', 'C', 'D', 'E'])



corr_matrix = df.corr()

sns.heatmap(corr_matrix, annot=True)

plt.title('Correlation Matrix')

plt.show()
